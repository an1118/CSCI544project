# %%
# !pip3 install wandb linformer performer_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 29.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 27.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2901 sha256=6bbc8113b7f0bcb8ebbafaff20e69b28e7c24b119fcd653e46ba654d7d0303d5
#   Stored in directory: /root/.cache/pip/wheels/e9/e0/51/fec72c3ac576d0559b7b3a328ec5dcbac4120cca74be9e49fc
# ...

# %%
# %cd /content/drive/MyDrive/CDIL-CNN/experiments/_3time
# !ls
# Out:
# /content/drive/MyDrive/CDIL-CNN/experiments/_3time
# dynamic.pyx	     noise_main.py   time_config.py	   time_main.py
# dynamic_setup.py     noise_train.py  time_datasets	   time_model
# noise_all.sh	     __pycache__     time_dynamic_main.py  time_train.py
# noise_generation.py  time_all.sh     time_log

# %%
# %cd /content/drive/MyDrive/CDIL-CNN/experiments/Models
# !ls
# Out:
# /content/drive/MyDrive/CDIL-CNN/experiments/Models
# net_conv.py  net_conv_rf.py  net_rnn.py  net_xformer.py  __pycache__  utils.py

# %%
# !python3 "time_main.py" --task RightWhaleCalls --model CDIL
# Out:
# position: 2000
# layer:1 	 distance:3 	 size:3
# layer:2 	 distance:7 	 size:7
# layer:3 	 distance:15 	 size:15
# layer:4 	 distance:31 	 size:31
# layer:5 	 distance:63 	 size:63
# layer:6 	 distance:127 	 size:127
# layer:7 	 distance:255 	 size:255
# layer:8 	 distance:511 	 size:511
# layer:9 	 distance:1023 	 size:1023
# layer:10 	 distance:2047 	 size:2047
# layer:11 	 distance:4000 	 size:4000
#
# Tesla T4
# RightWhaleCalls_P31650_CDIL_S1_L11_H32
# 100% 120/120 [00:18<00:00,  6.44it/s]
# Epoch: 0
# Train num: 7654 — Train loss: 0.5755930412896533 — Time: 18.628901
# 100% 52/52 [00:01<00:00, 43.69it/s]
# Val num: 3280 — Val loss: 0.5524718222094746 — Val accuracy: 71.46341463414633 — Time: 1.190489
# ________________________________________________________________________________
# 100% 31/31 [00:00<00:00, 45.86it/s]
# Test num: 1962 — Test loss: 0.5893258504060673 — Test accuracy: 70.54026503567789 — Time: 0.676408
# ...

# %% [markdown]
# # PositionalEncoding

# %%
# !python3 "time_main.py" --task RightWhaleCalls --model CDIL
# Out:
# position: 2000
# layer:1 	 distance:3 	 size:3
# layer:2 	 distance:7 	 size:7
# layer:3 	 distance:15 	 size:15
# layer:4 	 distance:31 	 size:31
# layer:5 	 distance:63 	 size:63
# layer:6 	 distance:127 	 size:127
# layer:7 	 distance:255 	 size:255
# layer:8 	 distance:511 	 size:511
# layer:9 	 distance:1023 	 size:1023
# layer:10 	 distance:2047 	 size:2047
# layer:11 	 distance:4000 	 size:4000
#
# Tesla T4
# RightWhaleCalls_P31650_CDIL_S1_L11_H32
# 100% 120/120 [00:18<00:00,  6.45it/s]
# Epoch: 0
# Train num: 7654 — Train loss: 0.6995010667536257 — Time: 18.605785
# 100% 52/52 [00:01<00:00, 43.76it/s]
# Val num: 3280 — Val loss: 0.6935291249577592 — Val accuracy: 49.298780487804876 — Time: 1.188682
# ________________________________________________________________________________
# 100% 31/31 [00:00<00:00, 43.43it/s]
# Test num: 1962 — Test loss: 0.6928688160140944 — Test accuracy: 50.35677879714577 — Time: 0.714914
# ...

# %% [markdown]
# # Positional Encoding with dim = 32

# %%
# !python3 "time_main.py" --task RightWhaleCalls --model CDIL
# Out:
# position: 2000
# layer:1 	 distance:3 	 size:3
# layer:2 	 distance:7 	 size:7
# layer:3 	 distance:15 	 size:15
# layer:4 	 distance:31 	 size:31
# layer:5 	 distance:63 	 size:63
# layer:6 	 distance:127 	 size:127
# layer:7 	 distance:255 	 size:255
# layer:8 	 distance:511 	 size:511
# layer:9 	 distance:1023 	 size:1023
# layer:10 	 distance:2047 	 size:2047
# layer:11 	 distance:4000 	 size:4000
#
# Tesla T4
# RightWhaleCalls_P34562_CDIL_S1_L11_H32
# 100% 120/120 [00:17<00:00,  6.70it/s]
# Epoch: 0
# Train num: 7654 — Train loss: 0.8215909620972318 — Time: 17.912444
# 100% 52/52 [00:01<00:00, 44.89it/s]
# Val num: 3280 — Val loss: 0.7035875384400531 — Val accuracy: 48.96341463414634 — Time: 1.158664
# ________________________________________________________________________________
# 100% 31/31 [00:00<00:00, 43.84it/s]
# Test num: 1962 — Test loss: 0.7008854071785308 — Test accuracy: 50.0 — Time: 0.708086
# ...

# %% [markdown]
# # lra Positional encoding with embedding Text Classification

# %%
# %cd /content/drive/MyDrive/CDIL-CNN/experiments/_2lra
# !ls
# Out:
# /content/drive/MyDrive/CDIL-CNN/experiments/_2lra
# create_datasets  lra_all.sh  lra_config.py  lra_main.py  lra_train.py

# %%
# %cd create_datasets/
# Out:
# /content/drive/MyDrive/CDIL-CNN/experiments/_2lra/create_datasets

# %%
# !python3 "text.py"
# Out:
# 2023-04-20 18:45:48.309487: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 18:45:49.357782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 2023-04-20 18:45:52.433992: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# ...

# %%
# !python3 "lra_main.py" --task text_4000 --model CDIL
# Out:
# position: 2000
# layer:1 	 distance:3 	 size:3
# layer:2 	 distance:7 	 size:7
# layer:3 	 distance:15 	 size:15
# layer:4 	 distance:31 	 size:31
# layer:5 	 distance:63 	 size:63
# layer:6 	 distance:127 	 size:127
# layer:7 	 distance:255 	 size:255
# layer:8 	 distance:511 	 size:511
# layer:9 	 distance:1023 	 size:1023
# layer:10 	 distance:2047 	 size:2047
# layer:11 	 distance:4000 	 size:4000
#
# Tesla T4
# text_4000_P153090_CDIL_S1_L11_H64
# Loaded ./lra_datasets/text_4000.train.pickle... size=25000
# Loaded ./lra_datasets/text_4000.dev.pickle... size=25000
# Loaded ./lra_datasets/text_4000.test.pickle... size=25000
# 100% 782/782 [01:30<00:00,  8.63it/s]
# Epoch: 0
# Train num: 25000 — Train loss: 0.7131259615707397 — Time: 90.659625
# 100% 782/782 [00:19<00:00, 39.59it/s]
# Val num: 25000 — Val loss: 0.6917892654418946 — Val accuracy: 51.304 — Time: 19.752455
# ________________________________________________________________________________
# ...

# %% [markdown]
# # Whale Sound DCT (no positional encoding)

# %%
# !pip3 install torch-dct
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 "time_main.py" --task RightWhaleCalls --model CDIL
# Out:
# position: 2000
# layer:1 	 distance:3 	 size:3
# layer:2 	 distance:7 	 size:7
# layer:3 	 distance:15 	 size:15
# layer:4 	 distance:31 	 size:31
# layer:5 	 distance:63 	 size:63
# layer:6 	 distance:127 	 size:127
# layer:7 	 distance:255 	 size:255
# layer:8 	 distance:511 	 size:511
# layer:9 	 distance:1023 	 size:1023
# layer:10 	 distance:2047 	 size:2047
# layer:11 	 distance:4000 	 size:4000
#
# Tesla T4
# RightWhaleCalls_P31650_CDIL_S1_L11_H32
# 100% 120/120 [00:16<00:00,  7.13it/s]
# Epoch: 0
# Train num: 7654 — Train loss: 0.5622351236246197 — Time: 16.824898
# 100% 52/52 [00:01<00:00, 43.33it/s]
# Val num: 3280 — Val loss: 0.5163773494522746 — Val accuracy: 73.47560975609755 — Time: 1.200568
# ________________________________________________________________________________
# 100% 31/31 [00:00<00:00, 44.03it/s]
# Test num: 1962 — Test loss: 0.5449410641715918 — Test accuracy: 71.9164118246687 — Time: 0.704842
# ...
